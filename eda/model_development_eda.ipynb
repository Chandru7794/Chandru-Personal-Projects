# %%
# %pip install duckdb
# Out:
# ...
#   Using cached duckdb-1.4.4-cp314-cp314-win_amd64.whl.metadata (4.3 kB)
# Using cached duckdb-1.4.4-cp314-cp314-win_amd64.whl (12.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb

# %%
con = duckdb.connect('data/workload.duckdb')
result=con.execute("SELECT * FROM stg_workload").workload()
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 con = duckdb.connect('data/workload.duckdb')
#       2 result=con.execute("SELECT * FROM stg_workload").workload()
#
# IOException: IO Error: Cannot open file "c:\machine learning projects\youtube workload\eda\data\workload.duckdb": The system cannot find the path specified.
