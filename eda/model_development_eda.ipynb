# %%
#%pip install duckdb
# Out:
# ...
#   Using cached duckdb-1.4.4-cp314-cp314-win_amd64.whl.metadata (4.3 kB)
# Using cached duckdb-1.4.4-cp314-cp314-win_amd64.whl (12.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb
import numpy 
import pandas as pd

# %%
con = duckdb.connect('../data/workload.duckdb')
workload=con.execute("SELECT * FROM stg_workload ORDER BY date_workflow::DATE, time_start").df()
con.close
# Out:
# <bound method pybind11_detail_function_record_v1_msvc_md_mscver19.close of <_duckdb.DuckDBPyConnection object at 0x000001C3FBD46330>>

# %%
workload.tail(50)
# Out:
#        media_type                      media_series     creation_category  \
# 4053       Movies  A Nightmare on Elm Street Series               Editing
# 4054       Movies  A Nightmare on Elm Street Series               Editing
# 4055       Movies  A Nightmare on Elm Street Series               Editing
# 4056       Movies  A Nightmare on Elm Street Series               Editing
# 4057       Movies  A Nightmare on Elm Street Series               Editing
# 4058       Movies  A Nightmare on Elm Street Series               Editing
# 4059       Movies  A Nightmare on Elm Street Series               Editing
# 4060       Movies  A Nightmare on Elm Street Series               Editing
# 4061       Movies  A Nightmare on Elm Street Series               Editing
# 4062       Movies  A Nightmare on Elm Street Series               Editing
# 4063       Movies  A Nightmare on Elm Street Series               Editing
# 4064       Movies  A Nightmare on Elm Street Series               Editing
# ...

# %%
pd.set_option('display.max_rows', 1000)

# %%
workload['date_workflow'].value_counts(dropna=False).sort_index()
# Out:
# date_workflow
# 2023-02-13     8
# 2023-02-14     3
# 2023-02-15     7
# 2023-02-16     4
# 2023-02-18     2
# 2023-02-19     2
# 2023-02-21     7
# 2023-02-22    10
# 2023-02-23     7
# 2023-02-24     6
# 2023-02-25     4
# 2023-02-27     1
# 2023-02-28     6
# 2023-03-01     5
# 2023-03-02     5
# 2023-03-06     2
# 2023-03-07    15
# 2023-03-08     6
# 2023-03-09     5
# 2023-03-10     2
# 2023-03-11     2
# 2023-03-13     5
# 2023-03-14    15
# 2023-03-15     9
# 2023-03-16     8
# 2023-03-20     3
# 2023-03-21     8
# 2023-03-22     1
# 2023-03-23     2
# 2023-03-24     5
# 2023-03-27     9
# 2023-03-28     5
# 2023-03-29     7
# 2023-03-30     9
# 2023-03-31     1
# 2023-04-01     2
# 2023-04-03     4
# 2023-04-04    12
# 2023-04-05     1
# 2023-04-06     4
# 2023-04-07     2
# 2023-04-08     1
# 2023-04-10     5
# 2023-04-11     2
# 2023-04-12     2
# 2023-04-13     3
# 2023-04-14     4
# 2023-04-17     4
# 2023-04-18     5
# 2023-04-19     8
# 2023-04-20     6
# ...

# %%
workload.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4103 entries, 0 to 4102
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   media_type         4103 non-null   str
#  1   media_series       4103 non-null   str
#  2   creation_category  4103 non-null   str
#  3   time_start         4103 non-null   str
#  4   time_end           4103 non-null   str
#  5   duration           4103 non-null   int64
#  6   media_title        4103 non-null   str
#  7   video_type         4103 non-null   str
#  8   video_subtype      4103 non-null   str
#  9   date_workflow      4103 non-null   datetime64[us]
#  10  month_year         4103 non-null   str
# dtypes: datetime64[us](1), int64(1), str(9)
# memory usage: 352.7 KB

# %%
# Out:
# 4146
# 4106
# 4103
